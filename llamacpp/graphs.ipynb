# %%
import json
import matplotlib.pyplot as plt
import os
from glob import glob

# Find all summary.json files
summary_files = sorted(glob("result_outputs/*m1/*summary.json", recursive=True))

# summary_files

# Define the percentiles and metric prefixes
percentiles = ["p25", "p50", "p75", "p90", "p95", "p99"]
metrics = {
    "Inter-token latency (s)": "results_inter_token_latency_s_quantiles_",
    "TTFT (s)": "results_ttft_s_quantiles_",
    "End-to-end latency (s)": "results_end_to_end_latency_s_quantiles_"
}

# Prepare storage for extracted data
data = {metric: {} for metric in metrics}

# Load and parse all summary files
for file in summary_files:
    with open(file) as f:
        summary = json.load(f)
        label = os.path.basename(os.path.dirname(file))  # Use the parent folder name as label
        for metric, prefix in metrics.items():
            data[metric][label] = [summary[f"{prefix}{p}"] for p in percentiles]

# Plotting
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=False)
x = range(len(percentiles))

for ax, (metric, values) in zip(axes, data.items()):
    for label, y in values.items():
        ax.plot(x, y, marker='o', label=label)
    ax.set_title(metric)
    ax.set_xticks(x)
    ax.set_xticklabels(percentiles)
    ax.set_ylabel("Seconds")
    ax.legend(fontsize="small", loc="upper left", bbox_to_anchor=(1, 1))
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import os
from glob import glob

# Find all summary.json files
summary_files = sorted(glob("result_outputs/*v100/*summary.json", recursive=True))

# Define the percentiles and metric prefixes
percentiles = ["p25", "p50", "p75", "p90", "p95", "p99"]
metrics = {
    "Inter-token latency (s)": "results_inter_token_latency_s_quantiles_",
    "TTFT (s)": "results_ttft_s_quantiles_",
    "End-to-end latency (s)": "results_end_to_end_latency_s_quantiles_"
}

# Prepare storage for extracted data
data = {metric: {} for metric in metrics}

# Load and parse all summary files
for file in summary_files:
    with open(file) as f:
        summary = json.load(f)
        label = os.path.basename(os.path.dirname(file))  # Use the parent folder name as label
        for metric, prefix in metrics.items():
            data[metric][label] = [summary[f"{prefix}{p}"] for p in percentiles]

# Plotting
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=False)
x = range(len(percentiles))

for ax, (metric, values) in zip(axes, data.items()):
    for label, y in values.items():
        ax.plot(x, y, marker='o', label=label)
    ax.set_title(metric)
    ax.set_xticks(x)
    ax.set_xticklabels(percentiles)
    ax.set_ylabel("Seconds")
    ax.legend(fontsize="small", loc="upper left", bbox_to_anchor=(1, 1))
    ax.grid(True)

plt.tight_layout()
plt.show()
